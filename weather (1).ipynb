# %%
import pandas as pd

# %%
weather = pd.read_csv("3663781.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1961-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1961-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1961-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1961-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1961-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2024-04-09  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-04-10  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-04-11  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-04-12  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-04-13  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
#              AWND  DAPR  FMTM  FRGT  MDPR   PGTM  ...  WT01  WT02  WT03  WT04  \
# DATE                                              ...
# 1961-01-01    NaN   NaN   NaN   NaN   NaN    NaN  ...   1.0   NaN   NaN   NaN
# 1961-01-02    NaN   NaN   NaN   NaN   NaN    NaN  ...   NaN   NaN   NaN   NaN
# 1961-01-03    NaN   NaN   NaN   NaN   NaN    NaN  ...   NaN   NaN   NaN   NaN
# 1961-01-04    NaN   NaN   NaN   NaN   NaN    NaN  ...   NaN   NaN   NaN   NaN
# 1961-01-05    NaN   NaN   NaN   NaN   NaN    NaN  ...   1.0   NaN   NaN   NaN
# ...           ...   ...   ...   ...   ...    ...  ...   ...   ...   ...   ...
# 2024-04-09   6.93   NaN   NaN   NaN   NaN    NaN  ...   NaN   NaN   NaN   NaN
# 2024-04-10   5.37   NaN   NaN   NaN   NaN    NaN  ...   1.0   NaN   NaN   NaN
# 2024-04-11   7.61   NaN   NaN   NaN   NaN    NaN  ...   NaN   NaN   NaN   NaN
# 2024-04-12  15.21   NaN   NaN   NaN   NaN    NaN  ...   NaN   NaN   NaN   NaN
# 2024-04-13  14.54   NaN   NaN   NaN   NaN  949.0  ...   1.0   NaN   NaN   NaN
#
#             WT05  WT07  WT08  WT09  WT16  WT18
# DATE
# 1961-01-01   NaN   NaN   1.0   NaN   NaN   NaN
# 1961-01-02   NaN   NaN   NaN   NaN   NaN   NaN
# 1961-01-03   NaN   NaN   1.0   NaN   NaN   NaN
# 1961-01-04   NaN   NaN   1.0   NaN   NaN   NaN
# 1961-01-05   NaN   NaN   1.0   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...
# 2024-04-09   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-10   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-11   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-12   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-13   NaN   NaN   NaN   NaN   NaN   NaN
#
# [17300 rows x 35 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.662197
# ACSH       0.662197
# AWND       0.487919
# DAPR       0.999538
# FMTM       0.873410
# FRGT       0.999884
# MDPR       0.999538
# PGTM       0.507919
# PRCP       0.016416
# SNOW       0.363353
# SNWD       0.356185
# TAVG       0.882254
# TMAX       0.000636
# TMIN       0.000809
# TSUN       0.933468
# WDF1       0.662197
# WDF2       0.487861
# WDF5       0.493006
# WDFG       0.753353
# WSF1       0.662197
# WSF2       0.487803
# WSF5       0.493006
# WSFG       0.753353
# WT01       0.774509
# WT02       0.979769
# WT03       0.992486
# WT04       0.999769
# WT05       0.998439
# WT07       0.999884
# WT08       0.820578
# WT09       0.999884
# WT16       0.892832
# WT18       0.999827
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1961-01-01    0.00   0.0         0.0      55.0      30.0
# 1961-01-02    0.00   0.0         0.0      54.0      32.0
# 1961-01-03    0.00   0.0         0.0      49.0      31.0
# 1961-01-04    0.00   0.0         0.0      51.0      31.0
# 1961-01-05    0.00   0.0         0.0      47.0      28.0
# ...            ...   ...         ...       ...       ...
# 2024-04-09    0.00   NaN         NaN      70.0      46.0
# 2024-04-10    0.00   NaN         NaN      74.0      48.0
# 2024-04-11    0.00   NaN         NaN      72.0      51.0
# 2024-04-12    0.00   NaN         NaN      62.0      50.0
# 2024-04-13    0.41   NaN         NaN      58.0      47.0
#
# [17300 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip         284
# snow          6286
# snow_depth    6162
# temp_max        11
# temp_min        14
# dtype: int64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    11013
# 1.0        1
# Name: snow, dtype: int64

# %%
del core_weather["snow"]

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    11138
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-12     NaN      63.0      55.0
# 1983-11-13     NaN      60.0      50.0
# ...            ...       ...       ...
# 2016-05-08     NaN      67.0      56.0
# 2017-10-28     NaN      68.0      50.0
# 2023-03-29     NaN      52.0      43.0
# 2023-12-06     NaN      61.0      47.0
# 2023-12-29     NaN      63.0      55.0
#
# [284 rows x 3 columns]

# %%
core_weather.loc["1983-10-20":"1983-11-05",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-20    0.00      73.0      52.0
# 1983-10-21    0.00      70.0      50.0
# 1983-10-22    0.00      70.0      50.0
# 1983-10-23    0.00      69.0      60.0
# 1983-10-24    0.00      73.0      58.0
# 1983-10-25    0.00      75.0      53.0
# 1983-10-26    0.00      79.0      53.0
# 1983-10-27    0.00      82.0      56.0
# 1983-10-28    0.00      74.0      56.0
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-01    0.26      69.0      60.0
# 1983-11-02    0.06      68.0      56.0
# 1983-11-03    0.00      68.0      56.0
# 1983-11-04    0.00      67.0      55.0
# 1983-11-05    0.00      66.0      51.0

# %%
core_weather.loc["2013-12-15",:]
# Out:
# precip       NaN
# temp_max    58.0
# temp_min    33.0
# Name: 2013-12-15, dtype: float64

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# 0.00    0.810347
# 0.01    0.025665
# 0.02    0.011618
# 0.03    0.007225
# 0.04    0.005954
#           ...
# 1.50    0.000058
# 1.38    0.000058
# 1.95    0.000058
# 2.01    0.000058
# 1.28    0.000058
# Name: precip, Length: 178, dtype: float64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip       0
# temp_max    11
# temp_min    14
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN
# 2022-10-08     0.0       NaN       NaN
# 2022-10-09     0.0       NaN       NaN
# 2022-10-10     0.0      69.0       NaN
# 2022-10-11     0.0      66.0       NaN

# %%
core_weather.loc["2011-12-18":"2011-12-28"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2011-12-18     0.0      52.0      33.0
# 2011-12-19     0.0      55.0      35.0
# 2011-12-20     0.0      61.0      35.0
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2011-12-26     0.0      50.0      32.0
# 2011-12-27     0.0      56.0      39.0
# 2011-12-28     0.0      57.0      38.0

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
# Check for missing value defined in data documentation
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04', '1961-01-05',
#        '1961-01-06', '1961-01-07', '1961-01-08', '1961-01-09', '1961-01-10',
#        ...
#        '2024-04-04', '2024-04-05', '2024-04-06', '2024-04-07', '2024-04-08',
#        '2024-04-09', '2024-04-10', '2024-04-11', '2024-04-12', '2024-04-13'],
#       dtype='object', name='DATE', length=17300)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '2024-04-04', '2024-04-05', '2024-04-06', '2024-04-07',
#                '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11',
#                '2024-04-12', '2024-04-13'],
#               dtype='datetime64[ns]', name='DATE', length=17300, freq=None)

# %%
core_weather.index.year
# Out:
# Int64Index([1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961,
#             ...
#             2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#            dtype='int64', name='DATE', length=17300)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    104
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()
# Out:
#       precip  temp_max  temp_min
# DATE
# 1961   13.87   24202.0   17819.0
# 1962   22.47   23785.0   17880.0
# 1963   19.11   23470.0   18237.0
# 1964   16.83   23013.0   18637.0
# 1965   16.32   23181.0   18715.0
# 1966   13.11   23680.0   18991.0
# 1967   23.98   23433.0   18668.0
# 1968   17.19   23634.0   18859.0
# 1969   25.70   23276.0   18493.0
# 1970   25.31   23465.0   18653.0
# 1971   10.61   22897.0   18084.0
# 1972   16.27   23262.0   18757.0
# 1973   29.37   23155.0   18445.0
# 1974   16.87   23289.0   18400.0
# 1975   17.54   23174.0   18150.0
# 1976    8.64   23859.0   18325.0
# 1977   11.70   23970.0   18884.0
# 1978   22.57   24112.0   18980.0
# 1979   23.79   23899.0   19107.0
# 1980   13.58   24064.0   18855.0
# 1983    7.13   12658.0   10316.0
# 1984   16.03   23998.0   18966.0
# 1985    8.50   23249.0   18461.0
# 1986    0.00   14112.0   11516.0
# 2000   21.09   23773.0   17841.0
# 2001   22.84   23890.0   17895.0
# 2002   19.12   24025.0   17840.0
# 2003   11.37   24384.0   18230.0
# 2004   12.97   24395.0   18213.0
# 2005   27.37   24012.0   18192.0
# 2006   22.79   24109.0   17944.0
# 2007   12.79   23964.0   17884.0
# 2008   13.86   24136.0   17819.0
# 2009   14.57   24019.0   17769.0
# 2010   22.67   24114.0   18363.0
# 2011   16.06   23873.0   17675.0
# 2012   22.93   23933.0   17686.0
# 2013    4.89   24689.0   17917.0
# 2014   19.62   25159.0   19017.0
# 2015    8.58   24941.0   18569.0
# 2016   19.77   24930.0   19102.0
# 2017   23.34   24901.0   18634.0
# 2018   16.82   24130.0   17990.0
# 2019   20.00   24896.0   18782.0
# 2020    6.42   25934.0   19021.0
# 2021   20.82   24506.0   18484.0
# 2022   15.38   24446.0   17901.0
# 2023   20.98   24041.0   18176.0
# 2024   11.56    6348.0    4860.0

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1961    13.87
# 1962    22.47
# 1963    19.11
# 1964    16.83
# 1965    16.32
# 1966    13.11
# 1967    23.98
# 1968    17.19
# 1969    25.70
# 1970    25.31
# 1971    10.61
# 1972    16.27
# 1973    29.37
# 1974    16.87
# 1975    17.54
# 1976     8.64
# 1977    11.70
# 1978    22.57
# 1979    23.79
# 1980    13.58
# 1983     7.13
# 1984    16.03
# 1985     8.50
# 1986     0.00
# 2000    21.09
# 2001    22.84
# 2002    19.12
# 2003    11.37
# 2004    12.97
# 2005    27.37
# 2006    22.79
# 2007    12.79
# 2008    13.86
# 2009    14.57
# 2010    22.67
# 2011    16.06
# 2012    22.93
# 2013     4.89
# 2014    19.62
# 2015     8.58
# 2016    19.77
# 2017    23.34
# 2018    16.82
# 2019    20.00
# 2020     6.42
# 2021    20.82
# 2022    15.38
# 2023    20.98
# 2024    11.56
# Name: precip, dtype: float64

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"] # target here show maximum temperature of next day

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1961-01-01    0.00      55.0      30.0    54.0
# 1961-01-02    0.00      54.0      32.0    49.0
# 1961-01-03    0.00      49.0      31.0    51.0
# 1961-01-04    0.00      51.0      31.0    47.0
# 1961-01-05    0.00      47.0      28.0    47.0
# ...            ...       ...       ...     ...
# 2024-04-09    0.00      70.0      46.0    74.0
# 2024-04-10    0.00      74.0      48.0    72.0
# 2024-04-11    0.00      72.0      51.0    62.0
# 2024-04-12    0.00      62.0      50.0    58.0
# 2024-04-13    0.41      58.0      47.0     NaN
#
# [17300 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1961-01-01     0.0      55.0      30.0    54.0
# 1961-01-02     0.0      54.0      32.0    49.0
# 1961-01-03     0.0      49.0      31.0    51.0
# 1961-01-04     0.0      51.0      31.0    47.0
# 1961-01-05     0.0      47.0      28.0    47.0
# ...            ...       ...       ...     ...
# 2024-04-08     0.0      66.0      42.0    70.0
# 2024-04-09     0.0      70.0      46.0    74.0
# 2024-04-10     0.0      74.0      48.0    72.0
# 2024-04-11     0.0      72.0      51.0    62.0
# 2024-04-12     0.0      62.0      50.0    58.0
#
# [17299 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=.3)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2020-12-31"]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1961-01-01    0.00      55.0      30.0    54.0
# 1961-01-02    0.00      54.0      32.0    49.0
# 1961-01-03    0.00      49.0      31.0    51.0
# 1961-01-04    0.00      51.0      31.0    47.0
# 1961-01-05    0.00      47.0      28.0    47.0
# ...            ...       ...       ...     ...
# 2020-12-27    0.00      63.0      44.0    61.0
# 2020-12-28    0.10      61.0      42.0    60.0
# 2020-12-29    0.00      60.0      39.0    56.0
# 2020-12-30    0.07      56.0      36.0    62.0
# 2020-12-31    0.06      62.0      44.0    60.0
#
# [16101 rows x 4 columns]

# %%
test = core_weather.loc["2021-01-01":]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2021-01-01    0.00      60.0      40.0    57.0
# 2021-01-02    0.14      57.0      51.0    56.0
# 2021-01-03    0.00      56.0      49.0    62.0
# 2021-01-04    0.36      62.0      46.0    59.0
# 2021-01-05    0.00      59.0      42.0    59.0
# ...            ...       ...       ...     ...
# 2024-04-08    0.00      66.0      42.0    70.0
# 2024-04-09    0.00      70.0      46.0    74.0
# 2024-04-10    0.00      74.0      48.0    72.0
# 2024-04-11    0.00      72.0      51.0    62.0
# 2024-04-12    0.00      62.0      50.0    58.0
#
# [1198 rows x 4 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.3)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(test["target"], predictions)
# Out:
# 18.96179065253109

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.802420
# 2021-01-02    56.0    59.305508
# 2021-01-03    62.0    58.532397
# 2021-01-04    59.0    61.532128
# 2021-01-05    59.0    59.440080
# ...            ...          ...
# 2024-04-08    70.0    64.487186
# 2024-04-09    74.0    68.088596
# 2024-04-10    72.0    71.331331
# 2024-04-11    62.0    70.427313
# 2024-04-12    58.0    63.037825
#
# [1198 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.1898524 ,  0.72101505,  0.17933744])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 18.339946454048256

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month, group_keys=False).apply(lambda x: x.expanding(1).mean())

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1961-01-31    0.10      64.0      54.0    63.0  55.466667       0.866667
# 1961-02-01    0.06      63.0      54.0    58.0  55.766667       0.885185
# 1961-02-02    0.17      58.0      54.0    63.0  56.066667       0.966667
# 1961-02-03    0.00      63.0      47.0    64.0  56.466667       0.896296
# 1961-02-04    0.00      64.0      43.0    64.0  57.033333       0.891146
# ...            ...       ...       ...     ...        ...            ...
# 2024-04-08    0.00      66.0      42.0    70.0  63.066667       0.955556
# 2024-04-09    0.00      70.0      46.0    74.0  63.366667       0.905238
# 2024-04-10    0.00      74.0      48.0    72.0  63.700000       0.860811
# 2024-04-11    0.00      72.0      51.0    62.0  64.033333       0.889352
# 2024-04-12    0.00      62.0      50.0    58.0  64.000000       1.032258
#
#              max_min  monthly_avg
# DATE
# 1961-01-31  1.185185    64.000000
# 1961-02-01  1.166667    63.000000
# 1961-02-02  1.074074    60.500000
# 1961-02-03  1.340426    61.333333
# 1961-02-04  1.488372    62.000000
# ...              ...          ...
# 2024-04-08  1.571429    64.494358
# 2024-04-09  1.521739    64.498238
# 2024-04-10  1.541667    64.504930
# 2024-04-11  1.411765    64.510204
# 2024-04-12  1.240000    64.508439
#
# [17269 rows x 8 columns]

# %%
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year,group_keys= False).apply(lambda x: x.expanding(1).mean())

# %%
predictors = ["precip", "temp_max", "temp_min", "month_max", "month_day_max", "max_min","day_of_year_avg","monthly_avg"]

# %%
error, combine = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 17.65498537649522

# %%
reg.coef_
# Out:
# array([ -0.94489351,   0.40901955,   0.03303018,   0.32469224,
#        -15.25108819,   0.05106373,   0.09135992,   0.13389176])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.206364
# temp_max           0.822053
# temp_min           0.595683
# target             1.000000
# month_max          0.689555
# month_day_max     -0.418938
# max_min            0.044853
# monthly_avg        0.691974
# day_of_year_avg    0.715242
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending = False).head()
# Out:
#             actual  predictions       diff
# DATE
# 2022-06-20    98.0    76.662722  21.337278
# 2022-05-23    86.0    69.389401  16.610599
# 2023-06-30    87.0    71.127081  15.872919
# 2023-08-29    91.0    75.345008  15.654992
# 2023-10-19    67.0    82.216379  15.216379

# %%
# doing prediction
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2023-12-31"]
    test = core_weather.loc["2024-04-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]
error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 22.945727151642817

# %%
reg.coef_
# Out:
# array([-1.68428733,  0.83692796,  0.12017267, 13.29506805,  0.13998391])

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month, group_keys=False).apply(lambda x: x.expanding(1).mean())
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year,group_keys= False).apply(lambda x: x.expanding(1).mean())

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1961-01-31    0.10      64.0      54.0    63.0  55.466667       0.866667
# 1961-02-01    0.06      63.0      54.0    58.0  55.766667       0.885185
# 1961-02-02    0.17      58.0      54.0    63.0  56.066667       0.966667
# 1961-02-03    0.00      63.0      47.0    64.0  56.466667       0.896296
# 1961-02-04    0.00      64.0      43.0    64.0  57.033333       0.891146
# ...            ...       ...       ...     ...        ...            ...
# 2024-04-08    0.00      66.0      42.0    70.0  63.066667       0.955556
# 2024-04-09    0.00      70.0      46.0    74.0  63.366667       0.905238
# 2024-04-10    0.00      74.0      48.0    72.0  63.700000       0.860811
# 2024-04-11    0.00      72.0      51.0    62.0  64.033333       0.889352
# 2024-04-12    0.00      62.0      50.0    58.0  64.000000       1.032258
#
#              max_min  monthly_avg  day_of_year_avg
# DATE
# 1961-01-31  1.185185    64.000000        64.000000
# 1961-02-01  1.166667    63.000000        63.000000
# 1961-02-02  1.074074    60.500000        58.000000
# 1961-02-03  1.340426    61.333333        63.000000
# 1961-02-04  1.488372    62.000000        64.000000
# ...              ...          ...              ...
# 2024-04-08  1.571429    64.494358        63.395833
# 2024-04-09  1.521739    64.498238        64.312500
# 2024-04-10  1.541667    64.504930        63.895833
# 2024-04-11  1.411765    64.510204        64.895833
# 2024-04-12  1.240000    64.508439        64.833333
#
# [17269 rows x 9 columns]

# %%
predictors = ["precip", "temp_max", "temp_min", "month_max", "month_day_max", "max_min","day_of_year_avg","monthly_avg"]
error, combine = create_predictions(predictors, core_weather, reg)
error
# Out:
# 21.26774502713945

# %%
reg.coef_
# Out:
# array([ -0.89778287,   0.408961  ,   0.03030623,   0.32393752,
#        -15.29610061,   0.04855567,   0.09510933,   0.13316423])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.206364
# temp_max           0.822053
# temp_min           0.595683
# target             1.000000
# month_max          0.689555
# month_day_max     -0.418938
# max_min            0.044853
# monthly_avg        0.691974
# day_of_year_avg    0.715242
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()
combined.sort_values("diff", ascending = False).head()
# Out:
#             actual  predictions      diff
# DATE
# 2024-04-11    62.0    69.575544  7.575544
# 2024-04-02    59.0    66.284646  7.284646
# 2024-04-09    74.0    67.527428  6.472572
# 2024-04-03    55.0    60.975390  5.975390
# 2024-04-08    70.0    64.374955  5.625045

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>
